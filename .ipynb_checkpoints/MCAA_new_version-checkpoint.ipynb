# %% [markdown]
# ## Imports ##

# %%
import numpy as np
import pandas as pd
import math
import sys
from numpy import random
from numpy import linalg
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Input ##

# %%
n_row = 2000
n_col = 1000
possibilities = [-1, 1]

# %%
W = np.random.normal(size = (n_row, n_col)) 
X = np.random.choice(possibilities, n_col)
Y = np.maximum((np.dot(W, X)/math.sqrt(n_col)), 0)
T = 0.1
B = 1/T
n_iter = 10000
N = 100

# %% [markdown]
# ## Helper functions ##

# %%
def energy(vector):
    dot = np.dot(W, vector)
    diff = Y - np.maximum(0, dot) / math.sqrt(n_col)
    return diff.T.dot(diff)

# %%
def error(vector):
    diff = vector - X
    return diff.T.dot(diff)/(4*n_col)

def plot(errors, names=[]):
    
    for error in errors:
        x, y = zip(*error)    
        plt.plot(np.array(x), np.array(y))
    
    plt.legend(names, loc='upper right')
    plt.ylabel('Error')
    plt.xlabel('Beta')

    plt.show()

# %%
def Metropolis_chain(dim, n_iter, params):
    print("Metropolis with initial parameters: {}".format(params))
    test = np.random.choice(possibilities, dim)
    
    errors = []
    betas = []
    
    last_update = 0
    
    B, range_size, progress_threshold, b_offset = params
        
    for _iter in range(n_iter):
        new_error = error(test)
        errors.append((_iter, new_error))
        betas.append(B)
        
        #if _iter % 1000 == 0 :
        #    print("error {0} at {1}".format(new_error, _iter))
            
        if _iter > range_size and last_update < _iter - range_size/5:
            progress = errors[_iter-range_size][1] - errors[_iter][1]
            if progress < progress_threshold:
                last_update = _iter
                B = B + b_offset
    
        to_flip = np.random.randint(0, dim)
        to_test = test.copy()
        to_test[to_flip] = -to_test[to_flip]
        proba = np.minimum(1, np.exp(-B*(energy(to_test)-energy(test))))
        if random.random() < proba:
            test = to_test
    
    print("After {0} iterations, B is {1} and error is {2}".format(n_iter, B, errors[-1][1]))
    return errors, betas

# %%
def Glauber(dim, n_iter, params):
    test = np.random.choice(possibilities, dim)
    
    errors = []
    
    errors = []
    betas = []
    
    last_update = 0
    
    B, range_size, progress_threshold, b_offset = params
    
    for _iter in range(n_iter):
        new_error = error(test)
        errors.append((_iter, new_error))
        betas.append(B)
        
        #if _iter % 1000 == 0 :
        #    print("error {0} at {1}".format(new_error, _iter))
            
        if _iter > range_size and last_update < _iter - range_size/5:
            progress = errors[_iter-range_size][1] - errors[_iter][1]
            if progress < progress_threshold:
                last_update = _iter
                B = B + b_offset
            
        to_flip = np.random.randint(0, dim)
        flipped = test.copy()
        flipped[to_flip] = test[to_flip]*-1
        proba = (1 + test[to_flip]*math.tanh(B*(energy(flipped) - energy(test))))/2.0
        if random.random() < proba:
            test[to_flip] = 1 
        else:
            test[to_flip] = -1
    
    print("After {0} iterations, B is {1} and error is {2}".format(n_iter, B, errors[-1][1]))
    return errors, betas

def save(liste, name="errors"):
    with open(name, 'wb') as fp:
        pickle.dump(liste, fp)

def read(name="errors"):
    with open (name, 'rb') as fp:
        return pickle.load(fp)

# %% [markdown]
# ## Bon Bail

# %%
# le troisieme paramettre fait parfois de la shit?

params = [(3, 152, 0.003, 0.01), (3, 152, 0.003, 0.03), (3, 152, 0.014, 0.01)]
for param in params:
    Glauber(n_col, n_iter, param)
# Out:
# After 10000 iterations, B is 4.549999999999967 and error is 0.101
# After 10000 iterations, B is 6.5700000000000145 and error is 0.074
# After 10000 iterations, B is 5.859999999999939 and error is 0.097

# %% [markdown]
# ## Grid Seach

# %%
# Metropolis
all_errors = []

for range_size in np.linspace(5, 300, 5):
    for progress_threshold in np.linspace(0.003, 0.014, 4):
        for offset_b in np.linspace(0.01, 0.03, 4):
            for beta in [0.5, 1, 2, 3]:
                range_size = int(range_size)
                errors, betas = Metropolis_chain(n_col, 5000, beta, range_size, progress_threshold, offset_b)
                params = beta, range_size, progress_threshold, offset_b
                all_errors.append((params, errors))
                
save(all_errors, "all_errors")
# Out:
# 0.519 0
# 0.379 1000
# 0.295 2000
# 0.253 3000
# 0.226 4000
# Final Beta is 25.100000000001124
# 0.518 0
# 0.39 1000
# 0.294 2000
# 0.237 3000
# 0.201 4000
# Final Beta is 25.72000000000122
# 0.496 0
# 0.329 1000
# 0.253 2000
# 0.201 3000
# 0.156 4000
# Final Beta is 26.520000000001346
# 0.509 0
# 0.389 1000
# 0.3 2000
# 0.26 3000
# 0.233 4000
# Final Beta is 27.63000000000154
# 0.505 0
# 0.346 1000
# 0.268 2000
# 0.221 3000
# 0.189 4000
# Final Beta is 41.39999999999893
# 0.501 0
# 0.357 1000
# 0.276 2000
# 0.23 3000
# 0.206 4000
# Final Beta is 41.98333333333223
# 0.488 0
# 0.358 1000
# 0.287 2000
# 0.249 3000
# 0.222 4000
# Final Beta is 43.31666666666549
# 0.519 0
# 0.378 1000
# 0.29 2000
# 0.214 3000
# 0.163 4000
# Final Beta is 43.833333333332135
# 0.488 0
# 0.35 1000
# 0.258 2000
# 0.2 3000
# 0.16 4000
# Final Beta is 57.830000000000226
# 0.478 0
# 0.324 1000
# 0.246 2000
# 0.204 3000
# 0.163 4000
# Final Beta is 58.49333333333357
# 0.529 0
# 0.365 1000
# 0.297 2000
# 0.231 3000
# 0.206 4000
# Final Beta is 59.33000000000023
# 0.536 0
# 0.379 1000
# 0.288 2000
# 0.238 3000
# 0.198 4000
# Final Beta is 60.49333333333357
# 0.508 0
# 0.373 1000
# 0.303 2000
# 0.248 3000
# 0.199 4000
# Final Beta is 74.60000000000207
# 0.505 0
# 0.359 1000
# 0.276 2000
# 0.225 3000
# 0.187 4000
# Final Beta is 74.68000000000207
# 0.518 0
# 0.368 1000
# 0.273 2000
# 0.215 3000
# 0.17 4000
# Final Beta is 75.3800000000021
# 0.493 0
# 0.358 1000
# 0.274 2000
# 0.222 3000
# 0.194 4000
# Final Beta is 77.01000000000217
# 0.495 0
# 0.354 1000
# 0.277 2000
# 0.217 3000
# 0.174 4000
# Final Beta is 25.470000000001182
# 0.491 0
# 0.343 1000
# 0.263 2000
# 0.199 3000
# 0.165 4000
# Final Beta is 25.97000000000126
# 0.496 0
# 0.356 1000
# 0.273 2000
# 0.214 3000
# 0.172 4000
# Final Beta is 26.970000000001416
# 0.503 0
# 0.36 1000
# 0.279 2000
# 0.235 3000
# 0.196 4000
# Final Beta is 27.970000000001594
# 0.505 0
# 0.356 1000
# 0.262 2000
# 0.204 3000
# 0.162 4000
# Final Beta is 42.11666666666556
# 0.516 0
# 0.345 1000
# 0.267 2000
# 0.224 3000
# 0.195 4000
# Final Beta is 42.61666666666553
# 0.513 0
# 0.356 1000
# 0.262 2000
# 0.192 3000
# 0.162 4000
# Final Beta is 43.61666666666547
# 0.504 0
# 0.347 1000
# 0.271 2000
# 0.229 3000
# 0.19 4000
# Final Beta is 44.616666666665424
# 0.513 0
# 0.353 1000
# 0.289 2000
# 0.24 3000
# 0.209 4000
# Final Beta is 58.76333333333356
# 0.522 0
# 0.338 1000
# 0.255 2000
# 0.213 3000
# 0.172 4000
# Final Beta is 59.26333333333357
# 0.5 0
# 0.334 1000
# 0.272 2000
# 0.235 3000
# 0.181 4000
# Final Beta is 60.26333333333357
# 0.471 0
# 0.344 1000
# 0.255 2000
# 0.212 3000
# 0.187 4000
# Final Beta is 61.26333333333357
# 0.457 0
# 0.32 1000
# 0.246 2000
# 0.194 3000
# 0.155 4000
# Final Beta is 75.4100000000021
# 0.496 0
# 0.35 1000
# 0.266 2000
# 0.202 3000
# 0.165 4000
# Final Beta is 75.91000000000211
# 0.508 0
# 0.367 1000
# 0.289 2000
# 0.215 3000
# 0.173 4000
# Final Beta is 76.91000000000216
# 0.524 0
# 0.372 1000
# 0.279 2000
# 0.251 3000
# 0.231 4000
# Final Beta is 77.9100000000022
# 0.476 0
# 0.357 1000
# 0.266 2000
# 0.197 3000
# 0.16 4000
# Final Beta is 25.470000000001182
# 0.499 0
# 0.312 1000
# 0.245 2000
# 0.201 3000
# 0.158 4000
# Final Beta is 25.97000000000126
# 0.514 0
# 0.349 1000
# 0.289 2000
# 0.245 3000
# 0.212 4000
# Final Beta is 26.970000000001416
# 0.494 0
# 0.354 1000
# 0.273 2000
# 0.227 3000
# 0.197 4000
# Final Beta is 27.970000000001594
# 0.496 0
# 0.361 1000
# 0.276 2000
# 0.224 3000
# 0.193 4000
# Final Beta is 42.11666666666556
# 0.519 0
# 0.362 1000
# 0.271 2000
# 0.213 3000
# 0.166 4000
# Final Beta is 42.61666666666553
# 0.495 0
# 0.349 1000
# 0.28 2000
# 0.229 3000
# 0.197 4000
# Final Beta is 43.61666666666547
# 0.512 0
# 0.34 1000
# 0.26 2000
# 0.225 3000
# 0.167 4000
# Final Beta is 44.616666666665424
# 0.531 0
# 0.351 1000
# 0.266 2000
# 0.211 3000
# 0.169 4000
# Final Beta is 58.76333333333356
# 0.517 0
# 0.363 1000
# 0.267 2000
# 0.216 3000
# 0.173 4000
# Final Beta is 59.26333333333357
# 0.508 0
# 0.357 1000
# 0.28 2000
# 0.218 3000
# 0.173 4000
# Final Beta is 60.26333333333357
# 0.5 0
# 0.347 1000
# 0.277 2000
# 0.237 3000
# 0.207 4000
# Final Beta is 61.26333333333357
# 0.533 0
# 0.36 1000
# 0.273 2000
# 0.219 3000
# 0.181 4000
# Final Beta is 75.4100000000021
# 0.508 0
# 0.314 1000
# 0.233 2000
# 0.19 3000
# 0.137 4000
# Final Beta is 75.91000000000211
# 0.486 0
# 0.354 1000
# 0.27 2000
# 0.214 3000
# 0.162 4000
# Final Beta is 76.91000000000216
# 0.501 0
# 0.338 1000
# 0.263 2000
# 0.206 3000
# 0.165 4000
# Final Beta is 77.9100000000022
# 0.508 0
# 0.373 1000
# 0.295 2000
# 0.241 3000
# 0.219 4000
# Final Beta is 25.470000000001182
# 0.469 0
# 0.328 1000
# 0.264 2000
# 0.221 3000
# 0.183 4000
# Final Beta is 25.97000000000126
# 0.497 0
# 0.345 1000
# 0.254 2000
# 0.198 3000
# 0.16 4000
# Final Beta is 26.970000000001416
# 0.48 0
# 0.328 1000
# 0.248 2000
# 0.211 3000
# 0.174 4000
# Final Beta is 27.970000000001594
# 0.477 0
# 0.33 1000
# 0.232 2000
# 0.181 3000
# 0.149 4000
# Final Beta is 42.11666666666556
# 0.513 0
# 0.361 1000
# 0.272 2000
# 0.223 3000
# 0.19 4000
# Final Beta is 42.61666666666553
# 0.506 0
# 0.348 1000
# 0.265 2000
# 0.227 3000
# 0.203 4000
# Final Beta is 43.61666666666547
# 0.533 0
# 0.368 1000
# 0.287 2000
# 0.244 3000
# 0.219 4000
# Final Beta is 44.616666666665424
# 0.507 0
# 0.318 1000
# 0.239 2000
# 0.193 3000
# 0.159 4000
# Final Beta is 58.76333333333356
# 0.502 0
# 0.345 1000
# 0.267 2000
# 0.221 3000
# 0.191 4000
# Final Beta is 59.26333333333357
# 0.524 0
# 0.354 1000
# 0.274 2000
# 0.214 3000
# 0.178 4000
# Final Beta is 60.26333333333357
# 0.498 0
# 0.335 1000
# 0.265 2000
# 0.188 3000
# 0.149 4000
# Final Beta is 61.26333333333357
# 0.509 0
# 0.355 1000
# 0.29 2000
# 0.237 3000
# 0.205 4000
# Final Beta is 75.4100000000021
# 0.491 0
# 0.362 1000
# 0.297 2000
# 0.235 3000
# 0.211 4000
# Final Beta is 75.91000000000211
# 0.482 0
# 0.349 1000
# 0.262 2000
# 0.219 3000
# 0.17 4000
# Final Beta is 76.91000000000216
# 0.485 0
# 0.328 1000
# 0.249 2000
# 0.206 3000
# 0.176 4000
# Final Beta is 77.9100000000022
# 0.493 0
# 0.345 1000
# 0.286 2000
# 0.235 3000
# 0.216 4000
# Final Beta is 2.0300000000000007
# 0.508 0
# 0.366 1000
# 0.276 2000
# 0.221 3000
# 0.16 4000
# Final Beta is 2.1599999999999975
# 0.496 0
# 0.36 1000
# 0.279 2000
# 0.226 3000
# 0.174 4000
# Final Beta is 3.079999999999977
# 0.5 0
# 0.341 1000
# 0.262 2000
# 0.209 3000
# 0.164 4000
# Final Beta is 4.219999999999974
# 0.472 0
# 0.383 1000
# 0.277 2000
# 0.236 3000
# 0.213 4000
# Final Beta is 2.949999999999995
# 0.491 0
# 0.358 1000
# 0.282 2000
# 0.218 3000
# 0.183 4000
# Final Beta is 2.999999999999993
# 0.476 0
# 0.34 1000
# 0.269 2000
# 0.216 3000
# 0.162 4000
# Final Beta is 3.999999999999993
# 0.488 0
# 0.353 1000
# 0.269 2000
# 0.209 3000
# 0.168 4000
# Final Beta is 4.9333333333333265
# 0.506 0
# 0.358 1000
# 0.296 2000
# 0.24 3000
# 0.182 4000
# Final Beta is 3.043333333333341
# 0.493 0
# 0.321 1000
# 0.252 2000
# 0.198 3000
# 0.174 4000
# Final Beta is 3.8700000000000117
# 0.499 0
# 0.343 1000
# 0.257 2000
# 0.218 3000
# 0.178 4000
# Final Beta is 5.0800000000000125
# 0.514 0
# 0.379 1000
# 0.294 2000
# 0.25 3000
# 0.204 4000
# Final Beta is 5.800000000000011
# 0.482 0
# 0.39 1000
# 0.305 2000
# 0.249 3000
# 0.215 4000
# Final Beta is 4.21999999999999
# 0.517 0
# 0.367 1000
# 0.261 2000
# 0.2 3000
# 0.143 4000
# Final Beta is 4.059999999999988
# 0.501 0
# 0.313 1000
# 0.252 2000
# 0.212 3000
# 0.149 4000
# Final Beta is 5.3599999999999985
# 0.528 0
# 0.35 1000
# 0.264 2000
# 0.2 3000
# 0.157 4000
# Final Beta is 5.9700000000000095
# 0.495 0
# 0.369 1000
# 0.307 2000
# 0.237 3000
# 0.191 4000
# Final Beta is 2.7299999999999858
# 0.511 0
# 0.375 1000
# 0.283 2000
# 0.216 3000
# 0.15 4000
# Final Beta is 3.0999999999999774
# 0.506 0
# 0.365 1000
# 0.281 2000
# 0.227 3000
# 0.194 4000
# Final Beta is 4.069999999999956
# 0.484 0
# 0.341 1000
# 0.254 2000
# 0.211 3000
# 0.17 4000
# Final Beta is 5.299999999999951
# 0.524 0
# 0.399 1000
# 0.289 2000
# 0.225 3000
# 0.197 4000
# Final Beta is 4.266666666666657
# 0.475 0
# 0.337 1000
# 0.266 2000
# 0.209 3000
# 0.158 4000
# Final Beta is 4.699999999999987
# 0.493 0
# 0.334 1000
# 0.263 2000
# 0.2 3000
# 0.176 4000
# Final Beta is 5.816666666666653
# 0.476 0
# 0.33 1000
# 0.233 2000
# 0.194 3000
# 0.166 4000
# Final Beta is 6.68333333333332
# 0.488 0
# 0.369 1000
# 0.291 2000
# 0.235 3000
# 0.184 4000
# Final Beta is 5.726666666666685
# 0.509 0
# 0.356 1000
# 0.249 2000
# 0.202 3000
# 0.15 4000
# Final Beta is 6.133333333333354
# 0.49 0
# 0.348 1000
# 0.263 2000
# 0.219 3000
# 0.196 4000
# Final Beta is 7.296666666666688
# 0.523 0
# 0.37 1000
# 0.292 2000
# 0.247 3000
# 0.207 4000
# Final Beta is 8.04000000000002
# 0.504 0
# 0.345 1000
# 0.279 2000
# 0.22 3000
# 0.17 4000
# Final Beta is 7.250000000000015
# 0.483 0
# 0.344 1000
# 0.266 2000
# 0.221 3000
# 0.182 4000
# Final Beta is 7.96000000000002
# 0.478 0
# 0.36 1000
# 0.271 2000
# 0.206 3000
# 0.16 4000
# Final Beta is 9.049999999999997
# 0.494 0
# 0.334 1000
# 0.258 2000
# 0.228 3000
# 0.193 4000
# Final Beta is 9.989999999999984
# 0.489 0
# 0.357 1000
# 0.296 2000
# 0.246 3000
# 0.204 4000
# Final Beta is 3.3399999999999728
# 0.508 0
# 0.38 1000
# 0.282 2000
# 0.22 3000
# 0.189 4000
# Final Beta is 3.679999999999965
# 0.513 0
# 0.363 1000
# 0.289 2000
# 0.242 3000
# 0.204 4000
# Final Beta is 4.759999999999941
# 0.501 0
# 0.352 1000
# 0.261 2000
# 0.21 3000
# 0.181 4000
# Final Beta is 5.759999999999941
# 0.495 0
# 0.365 1000
# 0.267 2000
# 0.207 3000
# 0.161 4000
# Final Beta is 5.13333333333332
# 0.472 0
# 0.359 1000
# 0.26 2000
# 0.201 3000
# 0.167 4000
# Final Beta is 5.61666666666665
# 0.513 0
# 0.338 1000
# 0.266 2000
# 0.209 3000
# 0.147 4000
# Final Beta is 6.533333333333317
# 0.51 0
# 0.349 1000
# 0.278 2000
# 0.211 3000
# 0.179 4000
# Final Beta is 7.466666666666651
# 0.508 0
# 0.357 1000
# 0.267 2000
# 0.223 3000
# 0.186 4000
# Final Beta is 6.706666666666689
# 0.493 0
# 0.36 1000
# 0.291 2000
# 0.237 3000
# 0.209 4000
# Final Beta is 7.580000000000027
# 0.506 0
# 0.357 1000
# 0.276 2000
# 0.225 3000
# 0.191 4000
# Final Beta is 8.416666666666693
# 0.506 0
# 0.359 1000
# 0.254 2000
# 0.209 3000
# 0.164 4000
# Final Beta is 9.346666666666692
# 0.477 0
# 0.367 1000
# 0.271 2000
# 0.227 3000
# 0.186 4000
# Final Beta is 8.780000000000005
# 0.503 0
# 0.379 1000
# 0.27 2000
# 0.204 3000
# 0.164 4000
# Final Beta is 9.099999999999998
# 0.497 0
# 0.336 1000
# 0.259 2000
# 0.198 3000
# 0.157 4000
# Final Beta is 10.189999999999973
# 0.522 0
# 0.38 1000
# 0.276 2000
# 0.227 3000
# 0.181 4000
# Final Beta is 11.039999999999962
# 0.533 0
# 0.407 1000
# 0.312 2000
# 0.24 3000
# 0.198 4000
# Final Beta is 3.4099999999999713
# 0.53 0
# 0.367 1000
# 0.264 2000
# 0.216 3000
# 0.186 4000
# Final Beta is 3.8399999999999617
# 0.512 0
# 0.346 1000
# 0.27 2000
# 0.235 3000
# 0.213 4000
# Final Beta is 4.849999999999939
# 0.513 0
# 0.361 1000
# 0.286 2000
# 0.228 3000
# 0.199 4000
# Final Beta is 5.899999999999938
# 0.481 0
# 0.34 1000
# 0.266 2000
# 0.217 3000
# 0.192 4000
# Final Beta is 5.349999999999986
# 0.497 0
# 0.343 1000
# 0.27 2000
# 0.225 3000
# 0.199 4000
# Final Beta is 5.749999999999983
# 0.526 0
# 0.373 1000
# 0.29 2000
# 0.229 3000
# 0.201 4000
# Final Beta is 6.883333333333316
# 0.511 0
# 0.363 1000
# 0.285 2000
# 0.246 3000
# 0.21 4000
# Final Beta is 7.849999999999983
# 0.518 0
# 0.391 1000
# 0.308 2000
# 0.264 3000
# 0.235 4000
# Final Beta is 7.4300000000000255
# 0.462 0
# 0.346 1000
# 0.258 2000
# 0.216 3000
# 0.168 4000
# Final Beta is 8.116666666666696
# 0.534 0
# 0.359 1000
# 0.261 2000
# 0.219 3000
# 0.177 4000
# Final Beta is 8.60333333333336
# 0.526 0
# 0.361 1000
# 0.265 2000
# 0.199 3000
# 0.162 4000
# Final Beta is 9.696666666666694
# 0.505 0
# 0.326 1000
# 0.251 2000
# 0.205 3000
# 0.169 4000
# Final Beta is 9.139999999999997
# 0.485 0
# 0.356 1000
# 0.258 2000
# 0.217 3000
# 0.182 4000
# Final Beta is 9.90999999999998
# 0.505 0
# 0.363 1000
# 0.275 2000
# 0.224 3000
# 0.189 4000
# Final Beta is 10.909999999999958
# 0.532 0
# 0.381 1000
# 0.282 2000
# 0.229 3000
# 0.184 4000
# Final Beta is 11.60999999999995
# 0.493 0
# 0.375 1000
# 0.31 2000
# 0.283 3000
# 0.229 4000
# Final Beta is 1.0500000000000005
# 0.529 0
# 0.377 1000
# 0.283 2000
# 0.238 3000
# 0.219 4000
# Final Beta is 1.4400000000000004
# 0.507 0
# 0.35 1000
# 0.279 2000
# 0.218 3000
# 0.185 4000
# Final Beta is 2.289999999999994
# 0.486 0
# 0.334 1000
# 0.245 2000
# 0.192 3000
# 0.147 4000
# Final Beta is 3.289999999999994
# 0.504 0
# 0.355 1000
# 0.325 2000
# 0.272 3000
# 0.247 4000
# Final Beta is 1.45
# 0.502 0
# 0.36 1000
# 0.297 2000
# 0.25 3000
# 0.192 4000
# Final Beta is 1.5666666666666647
# 0.509 0
# 0.342 1000
# 0.255 2000
# 0.202 3000
# 0.159 4000
# Final Beta is 2.6666666666666643
# 0.512 0
# 0.377 1000
# 0.289 2000
# 0.235 3000
# 0.196 4000
# Final Beta is 3.3666666666666654
# 0.505 0
# 0.349 1000
# 0.299 2000
# 0.253 3000
# 0.223 4000
# Final Beta is 1.783333333333336
# 0.49 0
# 0.357 1000
# 0.294 2000
# 0.23 3000
# 0.196 4000
# Final Beta is 1.81666666666667
# 0.482 0
# 0.329 1000
# 0.258 2000
# 0.213 3000
# 0.195 4000
# Final Beta is 2.7466666666666697
# 0.498 0
# 0.344 1000
# 0.226 2000
# 0.191 3000
# 0.154 4000
# Final Beta is 3.770000000000003
# 0.503 0
# 0.38 1000
# 0.304 2000
# 0.278 3000
# 0.237 4000
# Final Beta is 2.060000000000001
# 0.472 0
# 0.338 1000
# 0.271 2000
# 0.236 3000
# 0.197 4000
# Final Beta is 2.17
# 0.509 0
# 0.349 1000
# 0.269 2000
# 0.223 3000
# 0.214 4000
# Final Beta is 3.199999999999992
# 0.488 0
# 0.351 1000
# 0.26 2000
# 0.201 3000
# 0.165 4000
# Final Beta is 3.449999999999997
# 0.512 0
# 0.38 1000
# 0.335 2000
# 0.242 3000
# 0.23 4000
# Final Beta is 1.2800000000000007
# 0.524 0
# 0.37 1000
# 0.302 2000
# 0.244 3000
# 0.224 4000
# Final Beta is 1.6900000000000006
# 0.522 0
# 0.353 1000
# 0.279 2000
# 0.226 3000
# 0.198 4000
# Final Beta is 2.789999999999983
# 0.509 0
# 0.372 1000
# 0.279 2000
# 0.219 3000
# 0.164 4000
# Final Beta is 3.4899999999999896
# 0.496 0
# 0.368 1000
# 0.316 2000
# 0.288 3000
# 0.234 4000
# Final Beta is 1.833333333333332
# 0.515 0
# 0.357 1000
# 0.281 2000
# 0.235 3000
# 0.197 4000
# Final Beta is 2.183333333333329
# 0.495 0
# 0.341 1000
# 0.265 2000
# 0.203 3000
# 0.163 4000
# Final Beta is 2.98333333333333
# 0.499 0
# 0.329 1000
# 0.245 2000
# 0.181 3000
# 0.147 4000
# Final Beta is 4.183333333333329
# 0.478 0
# 0.377 1000
# 0.322 2000
# 0.273 3000
# 0.215 4000
# Final Beta is 2.2966666666666713
# 0.49 0
# 0.352 1000
# 0.287 2000
# 0.23 3000
# 0.178 4000
# Final Beta is 2.5400000000000063
# 0.525 0
# 0.35 1000
# 0.271 2000
# 0.224 3000
# 0.179 4000
# Final Beta is 3.470000000000006
# 0.461 0
# 0.325 1000
# 0.259 2000
# 0.214 3000
# 0.176 4000
# Final Beta is 4.70333333333334
# 0.491 0
# 0.373 1000
# 0.297 2000
# 0.226 3000
# 0.19 4000
# Final Beta is 2.689999999999997
# 0.497 0
# 0.354 1000
# 0.266 2000
# 0.205 3000
# 0.185 4000
# Final Beta is 3.399999999999992
# 0.52 0
# 0.331 1000
# 0.267 2000
# 0.208 3000
# 0.179 4000
# Final Beta is 3.9199999999999875
# 0.502 0
# 0.333 1000
# 0.241 2000
# 0.161 3000
# 0.123 4000
# Final Beta is 4.409999999999997
# 0.536 0
# 0.399 1000
# 0.319 2000
# 0.281 3000
# 0.212 4000
# Final Beta is 1.4500000000000008
# 0.487 0
# 0.352 1000
# 0.273 2000
# 0.223 3000
# 0.167 4000
# Final Beta is 2.04
# 0.497 0
# 0.346 1000
# 0.269 2000
# 0.217 3000
# 0.185 4000
# Final Beta is 3.0599999999999774
# 0.513 0
# 0.375 1000
# 0.279 2000
# 0.226 3000
# 0.19 4000
# Final Beta is 3.9999999999999787
# 0.493 0
# 0.382 1000
# 0.317 2000
# 0.258 3000
# 0.223 4000
# Final Beta is 2.2833333333333306
# 0.514 0
# 0.373 1000
# 0.299 2000
# 0.244 3000
# 0.216 4000
# Final Beta is 2.783333333333327
# 0.508 0
# 0.343 1000
# 0.259 2000
# 0.195 3000
# 0.173 4000
# Final Beta is 3.6333333333333275
# 0.515 0
# 0.354 1000
# 0.296 2000
# 0.251 3000
# 0.197 4000
# Final Beta is 4.899999999999993
# 0.503 0
# 0.355 1000
# 0.279 2000
# 0.215 3000
# 0.17 4000
# Final Beta is 2.9033333333333404
# 0.491 0
# 0.359 1000
# 0.283 2000
# 0.245 3000
# 0.199 4000
# Final Beta is 3.566666666666677
# 0.5 0
# 0.343 1000
# 0.237 2000
# 0.193 3000
# 0.139 4000
# Final Beta is 4.193333333333342
# 0.492 0
# 0.337 1000
# 0.254 2000
# 0.206 3000
# 0.168 4000
# Final Beta is 5.38000000000001
# 0.5 0
# 0.372 1000
# 0.279 2000
# 0.243 3000
# 0.207 4000
# Final Beta is 3.859999999999989
# 0.538 0
# 0.369 1000
# 0.298 2000
# 0.242 3000
# 0.19 4000
# Final Beta is 4.029999999999988
# 0.493 0
# 0.358 1000
# 0.282 2000
# 0.223 3000
# 0.184 4000
# Final Beta is 5.389999999999999
# 0.501 0
# 0.34 1000
# 0.255 2000
# 0.195 3000
# 0.152 4000
# Final Beta is 6.180000000000011
# 0.535 0
# 0.401 1000
# 0.314 2000
# 0.257 3000
# 0.232 4000
# Final Beta is 1.7800000000000011
# 0.514 0
# 0.324 1000
# 0.27 2000
# 0.22 3000
# 0.199 4000
# Final Beta is 2.2499999999999956
# 0.5 0
# 0.366 1000
# 0.265 2000
# 0.213 3000
# 0.183 4000
# Final Beta is 3.1499999999999755
# 0.491 0
# 0.333 1000
# 0.235 2000
# 0.17 3000
# 0.132 4000
# Final Beta is 4.0999999999999766
# 0.486 0
# 0.362 1000
# 0.308 2000
# 0.257 3000
# 0.209 4000
# Final Beta is 2.6166666666666627
# 0.488 0
# 0.332 1000
# 0.239 2000
# 0.191 3000
# 0.148 4000
# Final Beta is 2.9666666666666597
# 0.497 0
# 0.346 1000
# 0.271 2000
# 0.21 3000
# 0.175 4000
# Final Beta is 3.9333333333333265
# 0.479 0
# 0.315 1000
# 0.244 2000
# 0.193 3000
# 0.161 4000
# Final Beta is 4.96666666666666
# 0.517 0
# 0.382 1000
# 0.306 2000
# 0.237 3000
# 0.198 4000
# Final Beta is 3.4633333333333427
# 0.498 0
# 0.361 1000
# 0.287 2000
# 0.228 3000
# 0.184 4000
# Final Beta is 3.7066666666666777
# 0.507 0
# 0.362 1000
# 0.286 2000
# 0.228 3000
# 0.187 4000
# Final Beta is 4.846666666666678
# 0.498 0
# 0.35 1000
# 0.256 2000
# 0.185 3000
# 0.165 4000
# Final Beta is 5.800000000000011
# 0.499 0
# 0.388 1000
# 0.296 2000
# 0.234 3000
# 0.179 4000
# Final Beta is 4.129999999999989
# 0.512 0
# 0.369 1000
# 0.284 2000
# 0.231 3000
# 0.18 4000
# Final Beta is 4.659999999999993
# 0.493 0
# 0.336 1000
# 0.254 2000
# 0.22 3000
# 0.185 4000
# Final Beta is 5.449999999999999
# 0.489 0
# 0.361 1000
# 0.283 2000
# 0.218 3000
# 0.194 4000
# Final Beta is 6.900000000000017
# 0.561 0
# 0.395 1000
# 0.343 2000
# 0.323 3000
# 0.289 4000
# Final Beta is 0.8200000000000003
# 0.501 0
# 0.361 1000
# 0.293 2000
# 0.241 3000
# 0.213 4000
# Final Beta is 1.1600000000000001
# 0.498 0
# 0.361 1000
# 0.28 2000
# 0.227 3000
# 0.198 4000
# Final Beta is 2.149999999999997
# 0.525 0
# 0.38 1000
# 0.276 2000
# 0.223 3000
# 0.181 4000
# Final Beta is 3.0199999999999996
# 0.496 0
# 0.392 1000
# 0.33 2000
# 0.295 3000
# 0.267 4000
# Final Beta is 1.0166666666666682
# 0.467 0
# 0.325 1000
# 0.277 2000
# 0.211 3000
# 0.188 4000
# Final Beta is 1.4166666666666652
# 0.489 0
# 0.361 1000
# 0.254 2000
# 0.187 3000
# 0.152 4000
# Final Beta is 2.299999999999999
# 0.491 0
# 0.371 1000
# 0.283 2000
# 0.234 3000
# 0.206 4000
# Final Beta is 3.2333333333333325
# 0.512 0
# 0.373 1000
# 0.323 2000
# 0.276 3000
# 0.262 4000
# Final Beta is 1.340000000000001
# 0.481 0
# 0.334 1000
# 0.27 2000
# 0.231 3000
# 0.192 4000
# Final Beta is 1.5366666666666688
# 0.502 0
# 0.351 1000
# 0.257 2000
# 0.201 3000
# 0.176 4000
# Final Beta is 2.3500000000000014
# 0.525 0
# 0.371 1000
# 0.283 2000
# 0.225 3000
# 0.189 4000
# Final Beta is 3.2333333333333343
# 0.516 0
# 0.395 1000
# 0.337 2000
# 0.282 3000
# 0.246 4000
# Final Beta is 1.1900000000000006
# 0.495 0
# 0.382 1000
# 0.282 2000
# 0.23 3000
# 0.198 4000
# Final Beta is 1.6300000000000006
# 0.487 0
# 0.336 1000
# 0.249 2000
# 0.19 3000
# 0.161 4000
# Final Beta is 2.629999999999996
# 0.493 0
# 0.346 1000
# 0.259 2000
# 0.19 3000
# 0.156 4000
# Final Beta is 3.179999999999999
# 0.488 0
# 0.375 1000
# 0.303 2000
# 0.268 3000
# 0.241 4000
# Final Beta is 1.0000000000000004
# 0.473 0
# 0.332 1000
# 0.258 2000
# 0.237 3000
# 0.212 4000
# Final Beta is 1.4300000000000004
# 0.483 0
# 0.347 1000
# 0.276 2000
# 0.223 3000
# 0.181 4000
# Final Beta is 2.2699999999999942
# 0.496 0
# 0.365 1000
# 0.265 2000
# 0.231 3000
# 0.199 4000
# Final Beta is 3.3899999999999917
# 0.522 0
# 0.391 1000
# 0.33 2000
# 0.283 3000
# 0.267 4000
# Final Beta is 1.233333333333334
# 0.516 0
# 0.389 1000
# 0.31 2000
# 0.273 3000
# 0.225 4000
# Final Beta is 1.4499999999999984
# 0.516 0
# 0.357 1000
# 0.273 2000
# 0.233 3000
# 0.186 4000
# Final Beta is 2.3166666666666655
# 0.505 0
# 0.322 1000
# 0.251 2000
# 0.206 3000
# 0.179 4000
# Final Beta is 3.516666666666665
# 0.499 0
# 0.358 1000
# 0.311 2000
# 0.257 3000
# 0.243 4000
# Final Beta is 1.5733333333333352
# 0.508 0
# 0.324 1000
# 0.274 2000
# 0.235 3000
# 0.193 4000
# Final Beta is 1.980000000000004
# 0.499 0
# 0.349 1000
# 0.273 2000
# 0.233 3000
# 0.191 4000
# Final Beta is 2.5833333333333357
# 0.51 0
# 0.367 1000
# 0.284 2000
# 0.236 3000
# 0.187 4000
# Final Beta is 3.606666666666669
# 0.495 0
# 0.382 1000
# 0.304 2000
# 0.264 3000
# 0.223 4000
# Final Beta is 1.520000000000001
# 0.502 0
# 0.351 1000
# 0.27 2000
# 0.232 3000
# 0.198 4000
# Final Beta is 1.9600000000000009
# 0.503 0
# 0.346 1000
# 0.26 2000
# 0.205 3000
# 0.163 4000
# Final Beta is 2.8099999999999947
# 0.478 0
# 0.331 1000
# 0.262 2000
# 0.211 3000
# 0.167 4000
# Final Beta is 3.749999999999995
# 0.494 0
# 0.418 1000
# 0.336 2000
# 0.295 3000
# 0.259 4000
# Final Beta is 1.0500000000000005
# 0.518 0
# 0.331 1000
# 0.259 2000
# 0.214 3000
# 0.181 4000
# Final Beta is 1.5500000000000005
# 0.495 0
# 0.353 1000
# 0.269 2000
# 0.227 3000
# 0.182 4000
# Final Beta is 2.5299999999999887
# 0.492 0
# 0.353 1000
# 0.263 2000
# 0.214 3000
# 0.171 4000
# Final Beta is 3.4399999999999906
# 0.485 0
# 0.384 1000
# 0.334 2000
# 0.302 3000
# 0.228 4000
# Final Beta is 1.3500000000000003
# 0.521 0
# 0.374 1000
# 0.27 2000
# 0.233 3000
# 0.198 4000
# Final Beta is 1.9833333333333298
# 0.487 0
# 0.343 1000
# 0.248 2000
# 0.202 3000
# 0.185 4000
# Final Beta is 2.88333333333333
# 0.499 0
# 0.371 1000
# 0.293 2000
# 0.22 3000
# 0.176 4000
# Final Beta is 3.7499999999999973
# 0.485 0
# 0.381 1000
# 0.332 2000
# 0.282 3000
# 0.243 4000
# Final Beta is 1.783333333333336
# 0.509 0
# 0.349 1000
# 0.263 2000
# 0.221 3000
# 0.159 4000
# Final Beta is 2.026666666666671
# 0.474 0
# 0.328 1000
# 0.262 2000
# 0.206 3000
# 0.186 4000
# Final Beta is 3.4000000000000057
# 0.521 0
# 0.373 1000
# 0.286 2000
# 0.226 3000
# 0.177 4000
# Final Beta is 3.8866666666666703
# 0.502 0
# 0.382 1000
# 0.323 2000
# 0.254 3000
# 0.235 4000
# Final Beta is 2.0900000000000007
# 0.51 0
# 0.363 1000
# 0.303 2000
# 0.254 3000
# 0.209 4000
# Final Beta is 2.7099999999999964
# 0.505 0
# 0.33 1000
# 0.275 2000
# 0.217 3000
# 0.174 4000
# Final Beta is 3.7399999999999887
# 0.489 0
# 0.355 1000
# 0.253 2000
# 0.194 3000
# 0.154 4000
# Final Beta is 4.349999999999996
# 0.51 0
# 0.382 1000
# 0.307 2000
# 0.266 3000
# 0.241 4000
# Final Beta is 1.2200000000000006
# 0.47 0
# 0.328 1000
# 0.299 2000
# 0.23 3000
# 0.206 4000
# Final Beta is 1.7600000000000007
# 0.505 0
# 0.34 1000
# 0.268 2000
# 0.21 3000
# 0.171 4000
# Final Beta is 2.6299999999999866
# 0.51 0
# 0.359 1000
# 0.287 2000
# 0.238 3000
# 0.193 4000
# Final Beta is 3.6299999999999866
# 0.471 0
# 0.397 1000
# 0.314 2000
# 0.259 3000
# 0.229 4000
# Final Beta is 1.699999999999999
# 0.476 0
# 0.363 1000
# 0.28 2000
# 0.243 3000
# 0.204 4000
# Final Beta is 2.0833333333333295
# 0.517 0
# 0.35 1000
# 0.273 2000
# 0.221 3000
# 0.187 4000
# Final Beta is 3.099999999999996
# 0.515 0
# 0.364 1000
# 0.279 2000
# 0.233 3000
# 0.183 4000
# Final Beta is 3.98333333333333
# 0.506 0
# 0.416 1000
# 0.338 2000
# 0.271 3000
# 0.232 4000
# Final Beta is 2.110000000000004
# 0.511 0
# 0.354 1000
# 0.283 2000
# 0.227 3000
# 0.214 4000
# Final Beta is 2.6100000000000065
# 0.507 0
# 0.345 1000
# 0.261 2000
# 0.204 3000
# 0.159 4000
# Final Beta is 3.4466666666666725
# 0.514 0
# 0.352 1000
# 0.272 2000
# 0.224 3000
# 0.179 4000
# Final Beta is 4.516666666666673
# 0.525 0
# 0.366 1000
# 0.311 2000
# 0.268 3000
# 0.232 4000
# Final Beta is 2.6299999999999972
# 0.516 0
# 0.369 1000
# 0.289 2000
# 0.231 3000
# 0.193 4000
# Final Beta is 2.9799999999999947
# 0.481 0
# 0.343 1000
# 0.246 2000
# 0.198 3000
# 0.171 4000
# Final Beta is 3.9199999999999875
# 0.486 0
# 0.346 1000
# 0.265 2000
# 0.197 3000
# 0.162 4000
# Final Beta is 4.679999999999999
# 0.484 0
# 0.373 1000
# 0.303 2000
# 0.276 3000
# 0.259 4000
# Final Beta is 0.7700000000000002
# 0.511 0
# 0.354 1000
# 0.269 2000
# 0.256 3000
# 0.235 4000
# Final Beta is 1.1900000000000002
# 0.504 0
# 0.348 1000
# 0.255 2000
# 0.193 3000
# 0.165 4000
# Final Beta is 2.1199999999999974
# 0.539 0
# 0.369 1000
# 0.278 2000
# 0.238 3000
# 0.193 4000
# Final Beta is 3.039999999999999
# 0.497 0
# 0.387 1000
# 0.334 2000
# 0.319 3000
# 0.304 4000
# Final Beta is 0.8500000000000011
# 0.503 0
# 0.354 1000
# 0.293 2000
# 0.229 3000
# 0.202 4000
# Final Beta is 1.3666666666666654
# 0.51 0
# 0.361 1000
# 0.279 2000
# 0.224 3000
# 0.182 4000
# Final Beta is 2.0999999999999996
# 0.539 0
# 0.374 1000
# 0.285 2000
# 0.25 3000
# 0.21 4000
# Final Beta is 3.033333333333333
# 0.504 0
# 0.382 1000
# 0.31 2000
# 0.298 3000
# 0.263 4000
# Final Beta is 0.943333333333333
# 0.486 0
# 0.347 1000
# 0.275 2000
# 0.239 3000
# 0.211 4000
# Final Beta is 1.3733333333333348
# 0.524 0
# 0.35 1000
# 0.29 2000
# 0.244 3000
# 0.201 4000
# Final Beta is 2.0700000000000003
# 0.493 0
# 0.329 1000
# 0.247 2000
# 0.205 3000
# 0.171 4000
# Final Beta is 3.2566666666666677
# 0.499 0
# 0.369 1000
# 0.32 2000
# 0.317 3000
# 0.251 4000
# Final Beta is 1.0100000000000005
# 0.508 0
# 0.361 1000
# 0.3 2000
# 0.267 3000
# 0.227 4000
# Final Beta is 1.2400000000000002
# 0.486 0
# 0.331 1000
# 0.241 2000
# 0.199 3000
# 0.161 4000
# Final Beta is 2.149999999999999
# 0.497 0
# 0.339 1000
# 0.274 2000
# 0.245 3000
# 0.187 4000
# Final Beta is 3.0899999999999994
# 0.469 0
# 0.374 1000
# 0.339 2000
# 0.286 3000
# 0.261 4000
# Final Beta is 0.8600000000000003
# 0.495 0
# 0.342 1000
# 0.28 2000
# 0.223 3000
# 0.2 4000
# Final Beta is 1.3500000000000003
# 0.524 0
# 0.323 1000
# 0.254 2000
# 0.183 3000
# 0.14 4000
# Final Beta is 2.1299999999999972
# 0.511 0
# 0.36 1000
# 0.287 2000
# 0.226 3000
# 0.191 4000
# Final Beta is 3.1299999999999972
# 0.509 0
# 0.4 1000
# 0.346 2000
# 0.323 3000
# 0.257 4000
# Final Beta is 0.9333333333333347
# 0.515 0
# 0.367 1000
# 0.289 2000
# 0.245 3000
# 0.221 4000
# Final Beta is 1.4166666666666652
# 0.504 0
# 0.359 1000
# 0.279 2000
# 0.236 3000
# 0.221 4000
# Final Beta is 2.2666666666666657
# 0.469 0
# 0.325 1000
# 0.251 2000
# 0.2 3000
# 0.179 4000
# Final Beta is 3.299999999999999
# 0.519 0
# 0.401 1000
# 0.34 2000
# 0.298 3000
# 0.251 4000
# Final Beta is 1.0833333333333333
# 0.484 0
# 0.343 1000
# 0.264 2000
# 0.221 3000
# 0.195 4000
# Final Beta is 1.6066666666666691
# 0.508 0
# 0.356 1000
# 0.265 2000
# 0.213 3000
# 0.171 4000
# Final Beta is 2.4200000000000017
# 0.517 0
# 0.342 1000
# 0.282 2000
# 0.211 3000
# 0.182 4000
# Final Beta is 3.326666666666668
# 0.555 0
# 0.379 1000
# 0.321 2000
# 0.277 3000
# 0.244 4000
# Final Beta is 1.3100000000000007
# 0.484 0
# 0.364 1000
# 0.293 2000
# 0.258 3000
# 0.203 4000
# Final Beta is 1.5700000000000005
# 0.526 0
# 0.355 1000
# 0.286 2000
# 0.239 3000
# 0.192 4000
# Final Beta is 2.299999999999998
# 0.48 0
# 0.315 1000
# 0.247 2000
# 0.185 3000
# 0.153 4000
# Final Beta is 3.329999999999998
# 0.504 0
# 0.366 1000
# 0.339 2000
# 0.297 3000
# 0.282 4000
# Final Beta is 0.9700000000000004
# 0.504 0
# 0.352 1000
# 0.262 2000
# 0.208 3000
# 0.213 4000
# Final Beta is 1.3500000000000003
# 0.513 0
# 0.37 1000
# 0.282 2000
# 0.216 3000
# 0.194 4000
# Final Beta is 2.2699999999999942
# 0.506 0
# 0.347 1000
# 0.264 2000
# 0.212 3000
# 0.169 4000
# Final Beta is 3.2199999999999953
# 0.502 0
# 0.418 1000
# 0.341 2000
# 0.297 3000
# 0.261 4000
# Final Beta is 1.1000000000000012
# 0.515 0
# 0.381 1000
# 0.293 2000
# 0.273 3000
# 0.251 4000
# Final Beta is 1.5833333333333313
# 0.514 0
# 0.341 1000
# 0.257 2000
# 0.215 3000
# 0.2 4000
# Final Beta is 2.516666666666665
# 0.479 0
# 0.35 1000
# 0.274 2000
# 0.233 3000
# 0.191 4000
# Final Beta is 3.3666666666666654
# 0.507 0
# 0.396 1000
# 0.32 2000
# 0.267 3000
# 0.233 4000
# Final Beta is 1.3166666666666675
# 0.499 0
# 0.379 1000
# 0.291 2000
# 0.238 3000
# 0.23 4000
# Final Beta is 1.81666666666667
# 0.504 0
# 0.357 1000
# 0.285 2000
# 0.228 3000
# 0.188 4000
# Final Beta is 2.6766666666666694
# 0.486 0
# 0.346 1000
# 0.282 2000
# 0.238 3000
# 0.198 4000
# Final Beta is 3.606666666666669
# 0.465 0
# 0.379 1000
# 0.32 2000
# 0.298 3000
# 0.258 4000
# Final Beta is 1.550000000000001
# 0.498 0
# 0.361 1000
# 0.274 2000
# 0.228 3000
# 0.199 4000
# Final Beta is 1.8700000000000008
# 0.486 0
# 0.332 1000
# 0.26 2000
# 0.194 3000
# 0.165 4000
# Final Beta is 2.8699999999999943
# 0.503 0
# 0.34 1000
# 0.257 2000
# 0.179 3000
# 0.129 4000
# Final Beta is 3.3599999999999977
# 0.479 0
# 0.385 1000
# 0.31 2000
# 0.266 3000
# 0.242 4000
# Final Beta is 0.9600000000000004
# 0.492 0
# 0.393 1000
# 0.322 2000
# 0.25 3000
# 0.208 4000
# Final Beta is 1.3700000000000003
# 0.496 0
# 0.307 1000
# 0.236 2000
# 0.203 3000
# 0.168 4000
# Final Beta is 2.4399999999999906
# 0.497 0
# 0.334 1000
# 0.252 2000
# 0.198 3000
# 0.15 4000
# Final Beta is 3.289999999999994
# 0.516 0
# 0.396 1000
# 0.322 2000
# 0.285 3000
# 0.252 4000
# Final Beta is 1.2500000000000007
# 0.503 0
# 0.351 1000
# 0.283 2000
# 0.239 3000
# 0.194 4000
# Final Beta is 1.6666666666666643
# 0.491 0
# 0.336 1000
# 0.272 2000
# 0.211 3000
# 0.184 4000
# Final Beta is 2.6499999999999977
# 0.502 0
# 0.339 1000
# 0.274 2000
# 0.224 3000
# 0.199 4000
# Final Beta is 3.7333333333333307
# 0.481 0
# 0.367 1000
# 0.334 2000
# 0.283 3000
# 0.247 4000
# Final Beta is 1.503333333333335
# 0.501 0
# 0.359 1000
# 0.292 2000
# 0.255 3000
# 0.213 4000
# Final Beta is 2.0733333333333377
# 0.501 0
# 0.334 1000
# 0.251 2000
# 0.22 3000
# 0.173 4000
# Final Beta is 2.8866666666666703
# 0.517 0
# 0.365 1000
# 0.272 2000
# 0.216 3000
# 0.182 4000
# Final Beta is 3.81666666666667
# 0.533 0
# 0.398 1000
# 0.34 2000
# 0.301 3000
# 0.247 4000
# Final Beta is 1.7900000000000011
# 0.493 0
# 0.348 1000
# 0.295 2000
# 0.258 3000
# 0.22 4000
# Final Beta is 2.5599999999999974
# 0.499 0
# 0.327 1000
# 0.258 2000
# 0.206 3000
# 0.168 4000
# Final Beta is 3.1699999999999924
# 0.499 0
# 0.355 1000
# 0.274 2000
# 0.212 3000
# 0.17 4000
# Final Beta is 3.8399999999999945

# %%
all_errors = read("all_errors")
filtered = [(params, errors[-1][1]) for (params, errors) in all_errors if errors[-1][1] < 0.1]
filtered
# Out:
# [((3, 152, 0.006666666666666666, 0.03), 0.08),
#  ((3, 152, 0.014, 0.01), 0.085),
#  ((3, 300, 0.010333333333333333, 0.03), 0.095)]

# %%
errors_round2 = []
for (params, _) in filtered:
    tmp_errors = []
    
    beta, range_size, progress_threshold, offset_b = params
    for i in range(5):
        errors, betas = Metropolis_chain(n_col, 10000, beta, range_size, progress_threshold, offset_b)
        new_error = errors[-1][1]
        tmp_errors.append(new_error)
    avg_err = sum(tmp_errors)/len(tmp_errors)
    errors_round2.append((params, avg_err))
    
save(errors_round2, "errors_round2")
# Out:
# After 10000 iterations, B is 85.48333333332977 and error is 0.057
# After 10000 iterations, B is 85.73333333332975 and error is 0.013
# After 10000 iterations, B is 85.76666666666308 and error is 0.053
# After 10000 iterations, B is 85.76666666666308 and error is 0.006
# After 10000 iterations, B is 85.76666666666308 and error is 0.015
# After 10000 iterations, B is 116.49999999998448 and error is 0.01
# After 10000 iterations, B is 116.70999999998442 and error is 0.017
# After 10000 iterations, B is 116.26666666665122 and error is 0.022
# After 10000 iterations, B is 116.82666666665105 and error is 0.03
# After 10000 iterations, B is 116.7799999999844 and error is 0.036
# After 10000 iterations, B is 117.59666666665082 and error is 0.028
# After 10000 iterations, B is 117.59666666665082 and error is 0.014
# After 10000 iterations, B is 117.59666666665082 and error is 0.009
# After 10000 iterations, B is 117.59666666665082 and error is 0.043
# After 10000 iterations, B is 117.59666666665082 and error is 0.037
# After 10000 iterations, B is 150.41000000000494 and error is 0.023
# After 10000 iterations, B is 150.41000000000494 and error is 0.016
# After 10000 iterations, B is 150.41000000000494 and error is 0.032
# After 10000 iterations, B is 150.41000000000494 and error is 0.005
# After 10000 iterations, B is 150.41000000000494 and error is 0.019
# After 10000 iterations, B is 50.46999999999853 and error is 0.005
# After 10000 iterations, B is 50.46999999999853 and error is 0.005
# After 10000 iterations, B is 50.46999999999853 and error is 0.061
# After 10000 iterations, B is 50.46999999999853 and error is 0.024
# After 10000 iterations, B is 50.46999999999853 and error is 0.077
# After 10000 iterations, B is 50.96999999999843 and error is 0.036
# After 10000 iterations, B is 50.96999999999843 and error is 0.011
# After 10000 iterations, B is 50.96999999999843 and error is 0.075
# After 10000 iterations, B is 50.96999999999843 and error is 0.069
# After 10000 iterations, B is 50.96999999999843 and error is 0.012
# After 10000 iterations, B is 150.91000000000494 and error is 0.057
# After 10000 iterations, B is 150.91000000000494 and error is 0.002
# After 10000 iterations, B is 150.91000000000494 and error is 0.005
# After 10000 iterations, B is 150.91000000000494 and error is 0.057
# After 10000 iterations, B is 150.91000000000494 and error is 0.018
# After 10000 iterations, B is 152.91000000000503 and error is 0.069
# After 10000 iterations, B is 152.91000000000503 and error is 0.013
# After 10000 iterations, B is 152.91000000000503 and error is 0.036
# After 10000 iterations, B is 152.91000000000503 and error is 0.003
# After 10000 iterations, B is 152.91000000000503 and error is 0.098
# After 10000 iterations, B is 83.78333333332986 and error is 0.004
# After 10000 iterations, B is 83.78333333332986 and error is 0.051
# After 10000 iterations, B is 83.78333333332986 and error is 0.045
# After 10000 iterations, B is 83.78333333332986 and error is 0.002
# After 10000 iterations, B is 83.78333333332986 and error is 0.052
# After 10000 iterations, B is 119.59666666665021 and error is 0.002
# After 10000 iterations, B is 119.59666666665021 and error is 0.007
# After 10000 iterations, B is 119.59666666665021 and error is 0.039
# After 10000 iterations, B is 119.59666666665021 and error is 0.124
# After 10000 iterations, B is 119.59666666665021 and error is 0.044
# After 10000 iterations, B is 7.64999999999998 and error is 0.018
# After 10000 iterations, B is 7.74999999999998 and error is 0.067
# After 10000 iterations, B is 8.316666666666661 and error is 0.05
# After 10000 iterations, B is 7.683333333333313 and error is 0.004
# After 10000 iterations, B is 7.616666666666647 and error is 0.007
# After 10000 iterations, B is 11.169999999999954 and error is 0.018
# After 10000 iterations, B is 11.34999999999995 and error is 0.019
# After 10000 iterations, B is 10.809999999999961 and error is 0.01
# After 10000 iterations, B is 10.299999999999972 and error is 0.027
# After 10000 iterations, B is 11.589999999999945 and error is 0.016
# After 10000 iterations, B is 13.399999999999904 and error is 0.018
# After 10000 iterations, B is 12.64999999999992 and error is 0.003
# After 10000 iterations, B is 12.289999999999928 and error is 0.006
# After 10000 iterations, B is 12.529999999999923 and error is 0.006
# After 10000 iterations, B is 12.889999999999915 and error is 0.05
# After 10000 iterations, B is 14.099999999999897 and error is 0.042
# After 10000 iterations, B is 13.46999999999991 and error is 0.003
# After 10000 iterations, B is 13.43999999999991 and error is 0.037
# After 10000 iterations, B is 13.589999999999907 and error is 0.006
# After 10000 iterations, B is 13.109999999999918 and error is 0.02
# After 10000 iterations, B is 6.499999999999905 and error is 0.085
# After 10000 iterations, B is 6.26999999999991 and error is 0.016
# After 10000 iterations, B is 6.149999999999912 and error is 0.007
# After 10000 iterations, B is 6.26999999999991 and error is 0.006
# After 10000 iterations, B is 6.299999999999909 and error is 0.007
# After 10000 iterations, B is 9.983333333333407 and error is 0.011
# After 10000 iterations, B is 9.850000000000067 and error is 0.016
# After 10000 iterations, B is 9.666666666666725 and error is 0.024
# After 10000 iterations, B is 9.883333333333402 and error is 0.029
# After 10000 iterations, B is 9.850000000000067 and error is 0.016
# After 10000 iterations, B is 13.553333333333384 and error is 0.067
# After 10000 iterations, B is 13.436666666666717 and error is 0.011
# After 10000 iterations, B is 13.39000000000005 and error is 0.029
# After 10000 iterations, B is 14.043333333333386 and error is 0.067
# After 10000 iterations, B is 13.133333333333383 and error is 0.004
# After 10000 iterations, B is 17.209999999999894 and error is 0.005
# After 10000 iterations, B is 18.049999999999926 and error is 0.009
# After 10000 iterations, B is 18.40999999999994 and error is 0.013
# After 10000 iterations, B is 18.289999999999935 and error is 0.064
# After 10000 iterations, B is 17.92999999999992 and error is 0.003
# After 10000 iterations, B is 10.366666666666761 and error is 0.008
# After 10000 iterations, B is 10.316666666666759 and error is 0.024
# After 10000 iterations, B is 10.283333333333424 and error is 0.005
# After 10000 iterations, B is 10.150000000000084 and error is 0.013
# After 10000 iterations, B is 10.116666666666749 and error is 0.009
# After 10000 iterations, B is 10.866666666666784 and error is 0.025
# After 10000 iterations, B is 10.666666666666774 and error is 0.026
# After 10000 iterations, B is 10.683333333333442 and error is 0.001
# After 10000 iterations, B is 10.783333333333447 and error is 0.076
# After 10000 iterations, B is 10.783333333333447 and error is 0.015
# After 10000 iterations, B is 11.683333333333495 and error is 0.015
# After 10000 iterations, B is 11.800000000000168 and error is 0.003
# After 10000 iterations, B is 11.833333333333503 and error is 0.106
# After 10000 iterations, B is 11.7833333333335 and error is 0.014
# After 10000 iterations, B is 11.400000000000148 and error is 0.002
# After 10000 iterations, B is 14.976666666666723 and error is 0.003
# After 10000 iterations, B is 14.95333333333339 and error is 0.009
# After 10000 iterations, B is 15.09333333333339 and error is 0.007
# After 10000 iterations, B is 15.140000000000057 and error is 0.029
# After 10000 iterations, B is 14.95333333333339 and error is 0.004
# After 10000 iterations, B is 17.16333333333339 and error is 0.043
# After 10000 iterations, B is 17.16333333333339 and error is 0.003
# After 10000 iterations, B is 17.186666666666724 and error is 0.044
# After 10000 iterations, B is 17.116666666666724 and error is 0.028
# After 10000 iterations, B is 17.186666666666724 and error is 0.116
# After 10000 iterations, B is 3.8699999999999815 and error is 0.011
# After 10000 iterations, B is 3.9199999999999804 and error is 0.022
# After 10000 iterations, B is 4.019999999999978 and error is 0.005
# After 10000 iterations, B is 4.079999999999977 and error is 0.008
# After 10000 iterations, B is 3.979999999999979 and error is 0.003
# After 10000 iterations, B is 4.983333333333341 and error is 0.016
# After 10000 iterations, B is 5.146666666666675 and error is 0.004
# After 10000 iterations, B is 5.146666666666675 and error is 0.012
# After 10000 iterations, B is 5.893333333333345 and error is 0.067
# After 10000 iterations, B is 5.333333333333343 and error is 0.004
# After 10000 iterations, B is 5.7300000000000075 and error is 0.022
# After 10000 iterations, B is 5.580000000000006 and error is 0.01
# After 10000 iterations, B is 6.840000000000017 and error is 0.002
# After 10000 iterations, B is 6.180000000000011 and error is 0.005
# After 10000 iterations, B is 5.8500000000000085 and error is 0.007
# After 10000 iterations, B is 5.33999999999995 and error is 0.027
# After 10000 iterations, B is 5.069999999999956 and error is 0.002
# After 10000 iterations, B is 5.059999999999956 and error is 0.03
# After 10000 iterations, B is 5.0899999999999554 and error is 0.025
# After 10000 iterations, B is 5.409999999999949 and error is 0.047
# After 10000 iterations, B is 6.583333333333321 and error is 0.009
# After 10000 iterations, B is 6.566666666666654 and error is 0.019
# After 10000 iterations, B is 6.283333333333322 and error is 0.015
# After 10000 iterations, B is 6.499999999999988 and error is 0.011
# After 10000 iterations, B is 6.366666666666655 and error is 0.03
# After 10000 iterations, B is 8.300000000000013 and error is 0.029
# After 10000 iterations, B is 8.959999999999999 and error is 0.067
# After 10000 iterations, B is 8.390000000000011 and error is 0.034
# After 10000 iterations, B is 8.150000000000016 and error is 0.003
# After 10000 iterations, B is 8.180000000000016 and error is 0.037
# After 10000 iterations, B is 8.76000000000001 and error is 0.005
# After 10000 iterations, B is 9.509999999999994 and error is 0.018
# After 10000 iterations, B is 9.329999999999998 and error is 0.012
# After 10000 iterations, B is 9.24 and error is 0.021
# After 10000 iterations, B is 9.419999999999996 and error is 0.04
# After 10000 iterations, B is 8.370000000000026 and error is 0.063
# After 10000 iterations, B is 7.880000000000024 and error is 0.004
# After 10000 iterations, B is 8.206666666666692 and error is 0.046
# After 10000 iterations, B is 8.346666666666692 and error is 0.047
# After 10000 iterations, B is 8.090000000000025 and error is 0.005
# After 10000 iterations, B is 8.763333333333357 and error is 0.006
# After 10000 iterations, B is 9.090000000000025 and error is 0.029
# After 10000 iterations, B is 9.416666666666693 and error is 0.09
# After 10000 iterations, B is 8.996666666666691 and error is 0.022
# After 10000 iterations, B is 9.160000000000025 and error is 0.012
# After 10000 iterations, B is 11.429999999999954 and error is 0.011
# After 10000 iterations, B is 10.949999999999964 and error is 0.017
# After 10000 iterations, B is 11.009999999999962 and error is 0.002
# After 10000 iterations, B is 10.889999999999965 and error is 0.025
# After 10000 iterations, B is 10.979999999999963 and error is 0.051
# After 10000 iterations, B is 5.769999999999941 and error is 0.001
# After 10000 iterations, B is 5.719999999999942 and error is 0.004
# After 10000 iterations, B is 5.749999999999941 and error is 0.005
# After 10000 iterations, B is 5.759999999999941 and error is 0.004
# After 10000 iterations, B is 5.779999999999941 and error is 0.019
# After 10000 iterations, B is 5.783333333333316 and error is 0.043
# After 10000 iterations, B is 5.799999999999983 and error is 0.086
# After 10000 iterations, B is 5.6499999999999835 and error is 0.014
# After 10000 iterations, B is 5.633333333333317 and error is 0.019
# After 10000 iterations, B is 5.66666666666665 and error is 0.004
# After 10000 iterations, B is 7.8166666666666496 and error is 0.078
# After 10000 iterations, B is 7.799999999999983 and error is 0.136
# After 10000 iterations, B is 7.633333333333317 and error is 0.004
# After 10000 iterations, B is 7.466666666666651 and error is 0.002
# After 10000 iterations, B is 7.783333333333316 and error is 0.002
# After 10000 iterations, B is 2.6499999999999977 and error is 0.011
# After 10000 iterations, B is 2.633333333333331 and error is 0.032
# After 10000 iterations, B is 2.7833333333333306 and error is 0.044
# After 10000 iterations, B is 2.5666666666666647 and error is 0.017
# After 10000 iterations, B is 2.766666666666664 and error is 0.004
# After 10000 iterations, B is 4.679999999999999 and error is 0.055
# After 10000 iterations, B is 4.259999999999995 and error is 0.038
# After 10000 iterations, B is 4.019999999999993 and error is 0.013
# After 10000 iterations, B is 4.259999999999995 and error is 0.003
# After 10000 iterations, B is 3.929999999999994 and error is 0.004
# After 10000 iterations, B is 6.03000000000001 and error is 0.004
# After 10000 iterations, B is 5.790000000000008 and error is 0.033
# After 10000 iterations, B is 5.7300000000000075 and error is 0.009
# After 10000 iterations, B is 6.9300000000000175 and error is 0.054
# After 10000 iterations, B is 6.240000000000012 and error is 0.002
# After 10000 iterations, B is 4.360000000000014 and error is 0.016
# After 10000 iterations, B is 4.26666666666668 and error is 0.026
# After 10000 iterations, B is 4.19666666666668 and error is 0.007
# After 10000 iterations, B is 4.19666666666668 and error is 0.008
# After 10000 iterations, B is 4.383333333333347 and error is 0.026
# After 10000 iterations, B is 7.680000000000024 and error is 0.005
# After 10000 iterations, B is 7.6500000000000234 and error is 0.017
# After 10000 iterations, B is 7.2900000000000205 and error is 0.017
# After 10000 iterations, B is 7.440000000000022 and error is 0.005
# After 10000 iterations, B is 7.560000000000023 and error is 0.027
# After 10000 iterations, B is 7.920000000000026 and error is 0.015
# After 10000 iterations, B is 7.920000000000026 and error is 0.014
# After 10000 iterations, B is 8.070000000000025 and error is 0.013
# After 10000 iterations, B is 8.010000000000026 and error is 0.01
# After 10000 iterations, B is 8.190000000000023 and error is 0.034
# After 10000 iterations, B is 2.479999999999997 and error is 0.037
# After 10000 iterations, B is 2.6599999999999957 and error is 0.015
# After 10000 iterations, B is 2.479999999999997 and error is 0.019
# After 10000 iterations, B is 2.6899999999999955 and error is 0.02
# After 10000 iterations, B is 3.049999999999993 and error is 0.081
# After 10000 iterations, B is 2.619999999999987 and error is 0.0
# After 10000 iterations, B is 2.6399999999999864 and error is 0.049
# After 10000 iterations, B is 2.649999999999986 and error is 0.085
# After 10000 iterations, B is 2.4399999999999906 and error is 0.008
# After 10000 iterations, B is 2.7199999999999847 and error is 0.044
# After 10000 iterations, B is 4.319999999999996 and error is 0.012
# After 10000 iterations, B is 4.649999999999999 and error is 0.012
# After 10000 iterations, B is 4.199999999999995 and error is 0.011
# After 10000 iterations, B is 4.83 and error is 0.002
# After 10000 iterations, B is 4.83 and error is 0.074
# After 10000 iterations, B is 5.910000000000009 and error is 0.038
# After 10000 iterations, B is 5.7300000000000075 and error is 0.003
# After 10000 iterations, B is 5.580000000000006 and error is 0.006
# After 10000 iterations, B is 5.700000000000007 and error is 0.006
# After 10000 iterations, B is 5.640000000000007 and error is 0.02
# After 10000 iterations, B is 4.179999999999975 and error is 0.066
# After 10000 iterations, B is 4.219999999999974 and error is 0.032
# After 10000 iterations, B is 4.249999999999973 and error is 0.012
# After 10000 iterations, B is 4.1499999999999755 and error is 0.008
# After 10000 iterations, B is 4.1499999999999755 and error is 0.047
# After 10000 iterations, B is 5.329999999999998 and error is 0.025
# After 10000 iterations, B is 5.4799999999999995 and error is 0.022
# After 10000 iterations, B is 5.2399999999999975 and error is 0.016
# After 10000 iterations, B is 5.269999999999998 and error is 0.01
# After 10000 iterations, B is 5.51 and error is 0.001
# After 10000 iterations, B is 6.540000000000014 and error is 0.032
# After 10000 iterations, B is 6.300000000000012 and error is 0.018
# After 10000 iterations, B is 6.630000000000015 and error is 0.011
# After 10000 iterations, B is 6.6900000000000155 and error is 0.128
# After 10000 iterations, B is 6.0900000000000105 and error is 0.005

# %%
errors_round2 = read("errors_round2")
filtered = [(params, error) for params, error in errors_round2 if error < 0.01]
filtered
# Out:
# [((3, 152, 0.003, 0.01), 0.0098),
#  ((3, 152, 0.003, 0.03), 0.0092),
#  ((3, 152, 0.014, 0.01), 0.0066)]

# %%
repeat = 5
all_errors = np.zeros((len(filtered), n_iter))

for i, (params, _) in enumerate(filtered):
    mean_errors = np.zeros(n_iter)
    for j in range(repeat):
        errs, _ = Metropolis_chain(n_col, n_iter, params)
        mean_errors += np.array([tuple_[1] for tuple_ in errs])
    # Save mean errors    
    all_errors[i] = mean_errors / repeat
# Out:
# Metropolis with initial parameters: (3, 152, 0.003, 0.01)
# After 10000 iterations, B is 4.109999999999976 and error is 0.001
# Metropolis with initial parameters: (3, 152, 0.003, 0.01)
# After 10000 iterations, B is 4.139999999999976 and error is 0.004
# Metropolis with initial parameters: (3, 152, 0.003, 0.01)
# After 10000 iterations, B is 3.92999999999998 and error is 0.005
# Metropolis with initial parameters: (3, 152, 0.003, 0.01)
# After 10000 iterations, B is 4.129999999999976 and error is 0.004
# Metropolis with initial parameters: (3, 152, 0.003, 0.01)
# After 10000 iterations, B is 4.069999999999977 and error is 0.021
# Metropolis with initial parameters: (3, 152, 0.003, 0.03)
# After 10000 iterations, B is 6.390000000000013 and error is 0.055
# Metropolis with initial parameters: (3, 152, 0.003, 0.03)
# After 10000 iterations, B is 5.760000000000008 and error is 0.032
# Metropolis with initial parameters: (3, 152, 0.003, 0.03)
# After 10000 iterations, B is 5.7300000000000075 and error is 0.01
# Metropolis with initial parameters: (3, 152, 0.003, 0.03)
# After 10000 iterations, B is 5.400000000000005 and error is 0.005
# Metropolis with initial parameters: (3, 152, 0.003, 0.03)
# After 10000 iterations, B is 6.8100000000000165 and error is 0.067
# Metropolis with initial parameters: (3, 152, 0.014, 0.01)
# After 10000 iterations, B is 5.82999999999994 and error is 0.012
# Metropolis with initial parameters: (3, 152, 0.014, 0.01)
# After 10000 iterations, B is 5.80999999999994 and error is 0.004
# Metropolis with initial parameters: (3, 152, 0.014, 0.01)
# After 10000 iterations, B is 5.82999999999994 and error is 0.013
# Metropolis with initial parameters: (3, 152, 0.014, 0.01)
# After 10000 iterations, B is 5.759999999999941 and error is 0.001
# Metropolis with initial parameters: (3, 152, 0.014, 0.01)
# After 10000 iterations, B is 5.889999999999938 and error is 0.023

# %%
index_best_params = np.argmin(all_errors[:,-1]) # lowest last average error
best_params_metro = filtered[index_best_params]
best_errs_metro = all_errors[index_best_params]
print(best_params)
# Out:
# ((3, 152, 0.003, 0.01), 0.0098)

# %%
x = np.array(range(len(best_errs_metro)))

plt.figure(figsize=(15,7))
plt.title("Evolution of error in function of the number of iterations", size = 15)
#plt.plot(x, baseline_errs_glauber, color = 'cyan', label = 'baseline glauber')
#plt.plot(x, baseline_errs_metro, color = 'blue', label = 'baseline metropolis')
#plt.plot(x, best_errs_glauber, color = 'orange', label = 'best glauber')
plt.plot(x, best_errs_metro, color = 'blue', label = 'best metropolis')


plt.xlabel('Iteration number', size = 15)
plt.ylabel('Error', size = 15)
plt.legend(prop={'size': 15})
plt.show()

# %%
B_base = best_params[0][0]
range_size = best_params[0][1]
progress_threshold = best_params[0][2]
errs_base, _ = Metropolis_chain(n_col, n_iter, [B, range_size, progress_threshold, b_offset])

# %%
errs_test, betas_test = Metropolis_chain(n_col, n_iter, best_params[0])
# Out:
# Metropolis with initial parameters: (3, 152, 0.003, 0.01)
# After 10000 iterations, B is 4.089999999999977 and error is 0.009

# %%
x = np.array(range(len(best_errs_metro)))
data1 = [tuple_[1] for tuple_ in errs_test]
data2 = betas_test

fig, ax1 = plt.subplots(figsize=(10,7))

color = 'tab:red'
ax1.set_xlabel('Iteration number')
ax1.set_ylabel('error', color=color)
ax1.plot(x, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('beta', color=color)  # we already handled the x-label with ax1
ax2.plot(x, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title("Evolution of error and beta value over time")
plt.show()

# %%
progresses = []
range_size = 300

for (index, err) in enumerate(errors):
    if index > range_size:
        progress = errors[index-range_size][1] - err[1]
        progresses.append((index, progress))

# %%
plot([progresses])

# %%
t_tresholds
# Out:
# array([0.5 , 0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])

# %%
errors = []
for i in range(N):
    error = #Glauber ou Metropolis_chain selon best_set_up
    errors.append(error)
mean = np.mean(errors)
variance = np.var(errors)
print('Mean error : ', mean)
print('Variance of error : ' variance)

# %%
best_set_up
# Out:
# ('Metropolis', 'treshold :', 0.5, 'rate :', 5.0, 'error :', 0.015)

# %%
t_increasing = np.linspace(1.5, 5, num=8)
t_increasing
# Out:
# array([1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
BEST_SO_FAR = 0.01411756195508118 #Metropolis_chain(n_col, 100, B) 0.8
